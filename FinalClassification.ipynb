# %% [markdown]
# # CLASSIFICATION

# %% [markdown]
# ### CLASSIFICATION PLAN:
# We collected the labelled data from 2 different origins:
# 1. **KMeans Clustering** result (which will be called **original data**): 3 distinct classes, one of which is highly **imbalanced**
# 2. **Fuzzy Kmeans Clustering** result (which will be called **fuzzy data**): 3 distinct classes, not on same magnitude but also not particularly imbalanced
#
# Different approaches will be evaluated:
# * Apply classification on original train set i.e. high imbalance in data
# * Apply classification on oversampled original train set (robust oversampling method -> SMOTE)
# * Apply classification on oversampled original train set and test set (robust oversampling method -> SMOTE)
# * Apply classification on fuzzy train set i.e. more balanced data

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pydotplus 
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
from IPython.display import Image 
from collections import Counter
from imblearn.over_sampling import SMOTE
from scipy.stats import randint as sp_randint
from sklearn import tree
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.datasets import make_blobs
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.python.keras.utils.np_utils import to_categorical

# %% [markdown]
# ***

# %%
# UTILITY FUNCTIONS

# transform categorical attributes in numerical (all thanks and credits to Francesca, useful function!)
def discretize_data(dataset, variables):
    for variable in variables:
        #get the unique variable's values
        var = sorted(dataset[variable].unique())
        
        #generate a mapping from the variable's values to the number representation  
        mapping = dict(zip(var, range(0, len(var) + 1)))

        #add a new colum with the number representation of the variable
        dataset[variable+'_num'] = dataset[variable].map(mapping).astype(int)
    return dataset

# pretty printing of metrics computed on test set
def report_scores(test_label, test_pred):
    print(classification_report(test_label, 
                            test_pred, 
                            target_names=classes, zero_division=0)) 
# (to avoid exagerated warnings) zero division = 0 makes sure that no warnings are raised even if no classification on a certain class happens (and it can happen in multiple cases in this notebook)

# %% [markdown]
# ***

# %% [markdown]
# # WORKING ON ORIGINAL DATA

# %% [markdown]
# ***

# %%
# Starting dataset
df = pd.read_csv('datasets/clustered_dataframe.csv', sep='\t', index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4333 entries, 17850 to 12713
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   TProd           4333 non-null   int64
#  1   DProd           4333 non-null   int64
#  2   MeanProdOrder   4333 non-null   float64
#  3   TSale           4333 non-null   float64
#  4   MinPSale        4333 non-null   float64
#  5   MaxPSale        4333 non-null   float64
#  6   MeanSaleOrder   4333 non-null   float64
#  7   TRProd          4333 non-null   int64
#  8   MeanPSale       4333 non-null   float64
#  9   TOrder          4333 non-null   int64
#  10  SETSaleQta      4333 non-null   float64
#  11  SESaleQtaOrder  4333 non-null   float64
#  12  MaxOrderMonth   4333 non-null   object
#  13  Label           4333 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 507.8+ KB

# %%
# taking a look at data distribution between classes
for label in df['Label'].unique():
    print(label,"elements in dataset:",len(df[df['Label'] == label]))
# Out:
# Low_Spend elements in dataset: 3857
# Med_Spend elements in dataset: 450
# High_Spend elements in dataset: 26

# %%
# we only have 2 categorical attributes, discretize them and get rid of them (also get rid of attributes which lead in our experiments to bad classification)
df = discretize_data(df,['MaxOrderMonth','Label'])
df.drop(columns=['MaxOrderMonth','Label'], inplace=True, errors='ignore')
df.drop(columns=['SETSaleQta','SESaleQtaOrder','MinPSale','MaxPSale'], inplace=True, errors='ignore')
df_class = df.copy()
df_class.tail()
# Out:
#             TProd  DProd  MeanProdOrder   TSale  MeanSaleOrder  TRProd  \
# CustomerID
# 13436          76     12           76.0  196.89         196.89       0
# 15520         314     18          314.0  343.50         343.50       0
# 13298          96      2           96.0  360.00         360.00       0
# 14569          79     10           79.0  227.39         227.39       0
# 12713         505     37          505.0  794.55         794.55       0
#
#             MeanPSale  TOrder  MaxOrderMonth_num  Label_num
# CustomerID
# 13436           5.830       1                  2          1
# 15520           1.724       1                  2          1
# 13298           3.750       1                  2          1
# 14569           3.920       1                  2          1
# 12713           2.085       1                  2          2

# %%
# we keep true labels apart
label = df_class.pop('Label_num')
# we split dataset in train and test dataset. The use of stratify assures we keep correct class proportions in train and test
train_set, test_set, train_label, test_label = train_test_split(df_class, label, stratify = label, test_size=0.30)

# %% [markdown]
# ***

# %% [markdown]
# ## CLASSIFICATION on ORIGINAL TRAIN SET

# %% [markdown]
# ### Decision Tree (only for illustrating the method, we apply this to make an example of high explainability in classification)

# %%
# parameters based on various trial and errors
dt = tree.DecisionTreeClassifier(criterion='gini', splitter='best', 
                                  max_depth=10, 
                                  min_samples_split=3, min_samples_leaf=8)
dt = dt.fit(train_set, train_label)

# %%
# visualization of dt 
classes = ['High_Spend','Low_Spend','Med_Spend']
dot_data = tree.export_graphviz(dt, out_file=None, 
                         feature_names=list(train_set.columns),  
                         class_names=classes,  #in transforming to numerical this order is mapped to 0,1,2 because of lexicographical
                         filled=True, rounded=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %%
# predict and evaluate results on train and test set
train_pred_dt = dt.predict(train_set)
test_pred_dt = dt.predict(test_set)

print('Accuracy train set ', metrics.accuracy_score(train_label, train_pred_dt))
print('Accuracy test set ', metrics.accuracy_score(test_label, test_pred_dt))
print('Precision train set ', metrics.precision_score(train_label, train_pred_dt, average='weighted'))
print('Recall train set ', metrics.recall_score(train_label, train_pred_dt, average='weighted'))
print('F1 score train set ', metrics.f1_score(train_label, train_pred_dt, average='weighted'))
print('Support train set ', metrics.precision_recall_fscore_support(train_label, train_pred_dt))
# Out:
# Accuracy train set  0.9917573359709858
# Accuracy test set  0.9846153846153847
# Precision train set  0.9918776654426259
# Recall train set  0.9917573359709858
# F1 score train set  0.9917646709697172
# Support train set  (array([0.80952381, 0.99519586, 0.97385621]), array([0.94444444, 0.99740741, 0.94603175]), array([0.87179487, 0.99630041, 0.95974235]), array([  18, 2700,  315], dtype=int64))

# %%
report_scores(test_label, test_pred_dt)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.60      0.75      0.67         8
#    Low_Spend       0.99      0.99      0.99      1157
#    Med_Spend       0.94      0.91      0.92       135
#
#     accuracy                           0.98      1300
#    macro avg       0.84      0.89      0.86      1300
# weighted avg       0.99      0.98      0.98      1300

# %%
# plot confusion matrix
plot_confusion_matrix(dt, test_set, test_label)
plt.show()

# %% [markdown]
# ### Random Forest

# %% [markdown]
# **First do a grid search for correct parameter setting**

# %%
# define the parameter ranges we want to try, then run the grid search
num_estimators = 30
param_dist = {"max_depth": [3,5,6,7,8,9,10,11,12,None],
              "max_features": sp_randint(1, 10),
              "min_samples_split": sp_randint(3, 20),
              "min_samples_leaf": sp_randint(5, 20),
              "bootstrap": [True, False],
              "criterion": ["entropy", "gini"]}
n_iter_search = 50
clf = RandomForestClassifier(n_estimators=num_estimators)
grid_search = RandomizedSearchCV(clf, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=-1, 
                            scoring=make_scorer(accuracy_score))
grid_search.fit(train_set, train_label)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(n_estimators=30), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['entropy', 'gini'],
#                                         'max_depth': [3, 5, 6, 7, 8, 9, 10, 11,
#                                                       12, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FD97FE80>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FB9015E0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FB923D60>},
#                    scoring=make_scorer(accuracy_score))

# %%
# visualize insights on best performing model individuated
print('Best setting parameters ', grid_search.cv_results_['params'][0])
print('Mean and std of this setting ', grid_search.cv_results_['mean_test_score'][0], 
      grid_search.cv_results_['std_test_score'][0])
# Out:
# Best setting parameters  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 15, 'min_samples_split': 14}
# Mean and std of this setting  0.9858259796325596 0.0053682092314580685

# %%
# set and train the specified random forest
rf = RandomForestClassifier(n_estimators=30, 
                             criterion=grid_search.cv_results_['params'][0]['criterion'],
                             max_features=grid_search.cv_results_['params'][0]['max_features'],
                             max_depth=grid_search.cv_results_['params'][0]['max_depth'], 
                             min_samples_split=grid_search.cv_results_['params'][0]['min_samples_split'],
                             min_samples_leaf=grid_search.cv_results_['params'][0]['min_samples_leaf'],
                             bootstrap=grid_search.cv_results_['params'][0]['bootstrap']) 
rf = rf.fit(train_set, train_label)

# %%
# predict on test and visualize results
test_pred_rf = rf.predict(test_set)
report_scores(test_label, test_pred_rf)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       1.00      0.12      0.22         8
#    Low_Spend       0.99      1.00      1.00      1157
#    Med_Spend       0.92      0.96      0.94       135
#
#     accuracy                           0.99      1300
#    macro avg       0.97      0.69      0.72      1300
# weighted avg       0.99      0.99      0.98      1300

# %%
# forest is composed of lots of dt, visualize one just for fun
dot_data = tree.export_graphviz(rf[0], out_file=None, 
                         feature_names=list(train_set.columns),  
                         class_names=classes,
                         filled=True, rounded=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %% [markdown]
# ### Naive Bayes

# %%
# define and fit gaussian model, predict on test and see results
gnb = GaussianNB()
gnb.fit(train_set, train_label)

test_pred_gnb = gnb.predict(test_set)

report_scores(test_label,test_pred_gnb)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.64      0.88      0.74         8
#    Low_Spend       0.97      0.98      0.98      1157
#    Med_Spend       0.79      0.73      0.76       135
#
#     accuracy                           0.95      1300
#    macro avg       0.80      0.86      0.82      1300
# weighted avg       0.95      0.95      0.95      1300

# %% [markdown]
# ### KNN

# %%
# define and fit knn model, predict on test and see results
knn = KNeighborsClassifier(n_neighbors=5, algorithm='ball_tree', metric='minkowski').fit(train_set, train_label)

test_pred_knn = knn.predict(test_set)

report_scores(test_label,test_pred_knn)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       1.00      0.38      0.55         8
#    Low_Spend       0.98      1.00      0.99      1157
#    Med_Spend       0.93      0.79      0.85       135
#
#     accuracy                           0.97      1300
#    macro avg       0.97      0.72      0.79      1300
# weighted avg       0.97      0.97      0.97      1300

# %% [markdown]
# ### SVM

# %%
# define and fit svm model, predict on test and see results
svm = SVC(kernel='sigmoid', C=0.6, gamma='scale', probability=True)
svm.fit(train_set, train_label)

test_pred_svm = svm.predict(test_set)

report_scores(test_label, test_pred_svm)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.00      0.00      0.00         8
#    Low_Spend       0.91      0.98      0.95      1157
#    Med_Spend       0.46      0.16      0.24       135
#
#     accuracy                           0.89      1300
#    macro avg       0.46      0.38      0.40      1300
# weighted avg       0.86      0.89      0.87      1300

# %% [markdown]
# ***

# %% [markdown]
# ## CLASSIFICATION on OVERSAMPLED TRAIN SET (SMOTE)

# %% [markdown]
# **SMOTE** is a different stratification method which applies oversampling to the classes. The difference between this method and the basic oversampling applied before stands in the generation of new data:
# * in the basic oversampling, original data is simply copied to create exact (but additional) new data
# * in SMOTE oversampling, original data is used to create new data which copies the old one adding a [0,1] **perturbation**, hence generating truly new data

# %%
# create oversampled data
strat = {1: Counter(train_label)[1], 2: Counter(train_label)[2], 0: Counter(train_label)[2] }
smote = SMOTE(
    sampling_strategy=strat,    # resample all classes but the majority one
    k_neighbors=5
)

train_set_smote, train_label_smote = smote.fit_resample(train_set, train_label)

# %%
# visualize data distribution
Counter(train_label_smote)
# Out:
# Counter({1: 2700, 2: 315, 0: 315})

# %% [markdown]
# ### Random Forest

# %% [markdown]
# Try grid search again, on this more **balanced** dataset

# %%
# define and run the grid search
clf_smote = RandomForestClassifier(n_estimators=num_estimators)
grid_search_smote = RandomizedSearchCV(clf_smote, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=-1, 
                            scoring=make_scorer(accuracy_score))
grid_search_smote.fit(train_set_smote, train_label_smote)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(n_estimators=30), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['entropy', 'gini'],
#                                         'max_depth': [3, 5, 6, 7, 8, 9, 10, 11,
#                                                       12, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FD97FE80>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FB9015E0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FB923D60>},
#                    scoring=make_scorer(accuracy_score))

# %%
# visualize insights on best performing model individuated
print('Best setting parameters ', grid_search_smote.cv_results_['params'][0])
print('Mean and std of this setting ', grid_search_smote.cv_results_['mean_test_score'][0], 
      grid_search_smote.cv_results_['std_test_score'][0])
# Out:
# Best setting parameters  {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 8, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 19}
# Mean and std of this setting  0.9906906906906908 0.003344002620318326

# %%
# set and train the specified random forest
rf_smote = RandomForestClassifier(n_estimators=num_estimators, 
                             criterion=grid_search_smote.cv_results_['params'][0]['criterion'],
                             max_features=grid_search_smote.cv_results_['params'][0]['max_features'],
                             max_depth=grid_search_smote.cv_results_['params'][0]['max_depth'], 
                             min_samples_split=grid_search_smote.cv_results_['params'][0]['min_samples_split'],
                             min_samples_leaf=grid_search_smote.cv_results_['params'][0]['min_samples_leaf'],
                             bootstrap=grid_search_smote.cv_results_['params'][0]['bootstrap'])
rf_smote = rf_smote.fit(train_set_smote, train_label_smote)

# %%
# predict on test and visualize results
test_pred_rf = rf_smote.predict(test_set)
report_scores(test_label, test_pred_rf)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.86      0.75      0.80         8
#    Low_Spend       0.99      1.00      0.99      1157
#    Med_Spend       0.95      0.93      0.94       135
#
#     accuracy                           0.99      1300
#    macro avg       0.93      0.89      0.91      1300
# weighted avg       0.99      0.99      0.99      1300

# %% [markdown]
# ### Naive Bayes

# %%
# define and fit gaussian model, predict on test and see results
gnb = GaussianNB()
gnb.fit(train_set_smote, train_label_smote)

test_pred_gnb = gnb.predict(test_set)

report_scores(test_label,test_pred_gnb)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.54      0.88      0.67         8
#    Low_Spend       0.97      0.98      0.98      1157
#    Med_Spend       0.79      0.71      0.75       135
#
#     accuracy                           0.95      1300
#    macro avg       0.77      0.85      0.80      1300
# weighted avg       0.95      0.95      0.95      1300

# %% [markdown]
# ### KNN

# %%
# define and fit knn model, predict on test and see results
knn = KNeighborsClassifier(n_neighbors=5, algorithm='ball_tree', metric='minkowski').fit(train_set_smote, train_label_smote)

test_pred_knn = knn.predict(test_set)

report_scores(test_label,test_pred_knn)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.50      0.88      0.64         8
#    Low_Spend       0.98      1.00      0.99      1157
#    Med_Spend       0.96      0.73      0.83       135
#
#     accuracy                           0.97      1300
#    macro avg       0.81      0.87      0.82      1300
# weighted avg       0.97      0.97      0.97      1300

# %% [markdown]
# ### SVM

# %%
# define and fit svm model, predict on test and see results
svm = SVC(kernel='sigmoid', C=0.6, gamma='scale', probability=True)
svm.fit(train_set_smote, train_label_smote)

test_pred_svm = svm.predict(test_set)

report_scores(test_label, test_pred_svm)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.05      0.62      0.09         8
#    Low_Spend       0.91      0.95      0.93      1157
#    Med_Spend       0.00      0.00      0.00       135
#
#     accuracy                           0.85      1300
#    macro avg       0.32      0.52      0.34      1300
# weighted avg       0.81      0.85      0.83      1300

# %% [markdown]
# ***

# %% [markdown]
# ## CLASSIFICATION on OVERSAMPLED TRAIN SET and TEST SET (SMOTE)

# %%
# before starting classification we apply stratification to test set to have more data in less populated class
# we do this because otherwise our test set would be populated of < 10 elements for High_Spend class, giving a susceptible evaluation  
strat = {1: Counter(test_label)[1], 2: Counter(test_label)[2], 0: Counter(test_label)[2] }
smote = SMOTE(
    sampling_strategy=strat,    # resample all classes but the majority one
    k_neighbors=5
)
test_set, test_label = smote.fit_resample(test_set, test_label)

# visualize data distribution in TEST
Counter(test_label)
# Out:
# Counter({1: 1157, 2: 135, 0: 135})

# %%
plt.scatter(test_set.iloc[:, 4].values, test_set.iloc[:, 0].values, c=test_label.values, s=25, cmap='winter');

# %%
Counter(train_label_smote)
# Out:
# Counter({1: 2700, 2: 315, 0: 315})

# %% [markdown]
# ### Random Forest

# %% [markdown]
# Try grid search again, on this more balanced dataset

# %%
# define and run the grid search
clf_smote = RandomForestClassifier(n_estimators=num_estimators)
grid_search_smote = RandomizedSearchCV(clf_smote, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=-1, 
                            scoring=make_scorer(accuracy_score))
grid_search_smote.fit(train_set_smote, train_label_smote)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(n_estimators=30), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['entropy', 'gini'],
#                                         'max_depth': [3, 5, 6, 7, 8, 9, 10, 11,
#                                                       12, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FD97FE80>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FB9015E0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FB923D60>},
#                    scoring=make_scorer(accuracy_score))

# %%
# visualize insights on best performing model individuated
print('Best setting parameters ', grid_search_smote.cv_results_['params'][0])
print('Mean and std of this setting ', grid_search_smote.cv_results_['mean_test_score'][0], 
      grid_search_smote.cv_results_['std_test_score'][0])
# Out:
# Best setting parameters  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 8, 'max_features': 6, 'min_samples_leaf': 19, 'min_samples_split': 16}
# Mean and std of this setting  0.9876876876876877 0.0032063298054148086

# %%
# set and train the specified random forest
rf_smote = RandomForestClassifier(n_estimators=num_estimators, 
                             criterion=grid_search_smote.cv_results_['params'][0]['criterion'],
                             max_features=grid_search_smote.cv_results_['params'][0]['max_features'],
                             max_depth=grid_search_smote.cv_results_['params'][0]['max_depth'], 
                             min_samples_split=grid_search_smote.cv_results_['params'][0]['min_samples_split'],
                             min_samples_leaf=grid_search_smote.cv_results_['params'][0]['min_samples_leaf'],
                             bootstrap=grid_search_smote.cv_results_['params'][0]['bootstrap'])
rf_smote = rf_smote.fit(train_set_smote, train_label_smote)

# %%
# predict on test and visualize results
test_pred_rf = rf_smote.predict(test_set)
report_scores(test_label, test_pred_rf)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.96      0.91      0.94       135
#    Low_Spend       1.00      1.00      1.00      1157
#    Med_Spend       0.88      0.93      0.91       135
#
#     accuracy                           0.98      1427
#    macro avg       0.95      0.95      0.95      1427
# weighted avg       0.98      0.98      0.98      1427

# %% [markdown]
# ### Naive Bayes

# %%
# define and fit gaussian model, predict on test and see results
gnb = GaussianNB()
gnb.fit(train_set_smote, train_label_smote)

test_pred_gnb = gnb.predict(test_set)

report_scores(test_label,test_pred_gnb)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.94      0.71      0.81       135
#    Low_Spend       0.97      0.98      0.98      1157
#    Med_Spend       0.60      0.71      0.65       135
#
#     accuracy                           0.93      1427
#    macro avg       0.84      0.80      0.81      1427
# weighted avg       0.93      0.93      0.93      1427

# %% [markdown]
# ### KNN

# %%
# define and fit gaussian model, predict on test and see results
knn = KNeighborsClassifier(n_neighbors=5, algorithm='ball_tree', metric='minkowski').fit(train_set_smote, train_label_smote)

test_pred_knn = knn.predict(test_set)

report_scores(test_label,test_pred_knn)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.94      0.83      0.88       135
#    Low_Spend       0.98      1.00      0.99      1157
#    Med_Spend       0.79      0.73      0.76       135
#
#     accuracy                           0.96      1427
#    macro avg       0.90      0.85      0.88      1427
# weighted avg       0.95      0.96      0.96      1427

# %% [markdown]
# ### SVM

# %%
# define and fit gaussian model, predict on test and see results
svm = SVC(kernel='sigmoid', C=0.6, gamma='scale', probability=True)
svm.fit(train_set_smote, train_label_smote)

test_pred_svm = svm.predict(test_set)

report_scores(test_label, test_pred_svm)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.50      0.70      0.58       135
#    Low_Spend       0.89      0.95      0.91      1157
#    Med_Spend       0.00      0.00      0.00       135
#
#     accuracy                           0.83      1427
#    macro avg       0.46      0.55      0.50      1427
# weighted avg       0.77      0.83      0.80      1427

# %% [markdown]
# ***

# %% [markdown]
# # WORKING ON FUZZY DATA

# %%
# Starting dataset
df_f = pd.read_csv('datasets/clustered_fuzzy_dataframe.csv', sep='\t', index_col=0)

# %%
# we only have 2 categorical attributes, discretize them and get rid of them (also get rid of attributes which lead in our experiments to bad classification)
df_f = discretize_data(df_f,['MaxOrderMonth','Label'])
df_f.drop(columns=['MaxOrderMonth','Label', 'MaxOrderDay'], inplace=True, errors='ignore')
df_f.drop(columns=['SETSaleQta','SESaleQtaOrder','MinPSale','MaxPSale'], inplace=True, errors='ignore')
df_f_class = df_f.copy()

# %%
# we keep true labels apart
label = df_f_class.pop('Label_num')
# we split dataset in train and test dataset. The use of stratify assures we keep correct class proportions in train and test
train_set_f, test_set_f, train_label_f, test_label_f = train_test_split(df_f_class, label, stratify = label, test_size=0.30)

# %% [markdown]
# ***

# %% [markdown]
# ### Decision Tree (only for illustrating the method, we apply this to make an example of high explainability in classification)

# %%
# parameters based on various trial and errors
dt_f = tree.DecisionTreeClassifier(criterion='gini', splitter='best', 
                                  max_depth=6, 
                                  min_samples_split=3, min_samples_leaf=8)
dt_f = dt_f.fit(train_set_f, train_label_f)

# %%
# visualization of dt
dot_data_f = tree.export_graphviz(dt_f, out_file=None, 
                         feature_names=list(train_set_f.columns),  
                         class_names=classes,  #in transforming to numerical this order is mapped to 0,1,2 because of lexicographical
                         filled=True, rounded=True)  
graph = pydotplus.graph_from_dot_data(dot_data_f)  
Image(graph.create_png())

# %%
# predict on train and test set
train_pred_dt_f = dt_f.predict(train_set_f)
test_pred_dt_f = dt_f.predict(test_set_f)

# %%
# visualize results
report_scores(test_label_f, test_pred_dt_f)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.96      0.94      0.95        48
#    Low_Spend       0.99      0.99      0.99       925
#    Med_Spend       0.95      0.96      0.96       327
#
#     accuracy                           0.98      1300
#    macro avg       0.97      0.96      0.96      1300
# weighted avg       0.98      0.98      0.98      1300

# %% [markdown]
# ### Random Forest

# %% [markdown]
# **Do a grid search for correct parameter setting**

# %%
# define the parameter ranges we want to try, then run the grid search
clf_f = RandomForestClassifier(n_estimators=30)
grid_search_f = RandomizedSearchCV(clf_f, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=-1, 
                            scoring=make_scorer(accuracy_score))
grid_search_f.fit(train_set_f, train_label_f)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(n_estimators=30), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['entropy', 'gini'],
#                                         'max_depth': [3, 5, 6, 7, 8, 9, 10, 11,
#                                                       12, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FD97FE80>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FB9015E0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000285FB923D60>},
#                    scoring=make_scorer(accuracy_score))

# %%
# visualize insights on best performing model individuated
print('Best setting parameters ', grid_search_f.cv_results_['params'][0])
print('Mean and std of this setting ', grid_search_f.cv_results_['mean_test_score'][0], 
      grid_search_f.cv_results_['std_test_score'][0])
# Out:
# Best setting parameters  {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 11, 'max_features': 9, 'min_samples_leaf': 17, 'min_samples_split': 10}
# Mean and std of this setting  0.9666971145219957 0.010857112188607389

# %%
# set and train the specified random forest
rf_f = RandomForestClassifier(n_estimators=num_estimators, 
                             criterion=grid_search_f.cv_results_['params'][0]['criterion'],
                             max_features=grid_search_f.cv_results_['params'][0]['max_features'],
                             max_depth=grid_search_f.cv_results_['params'][0]['max_depth'], 
                             min_samples_split=grid_search_f.cv_results_['params'][0]['min_samples_split'],
                             min_samples_leaf=grid_search_f.cv_results_['params'][0]['min_samples_leaf'],
                             bootstrap=grid_search_f.cv_results_['params'][0]['bootstrap']) 
rf_f = rf_f.fit(train_set_f, train_label_f)

# %%
# predict on test and visualize results
test_pred_rf_f = rf_f.predict(test_set_f)
report_scores(test_label_f, test_pred_rf_f)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.96      0.94      0.95        48
#    Low_Spend       0.99      0.99      0.99       925
#    Med_Spend       0.95      0.96      0.96       327
#
#     accuracy                           0.98      1300
#    macro avg       0.97      0.96      0.96      1300
# weighted avg       0.98      0.98      0.98      1300

# %%
# forest is composed of lots of dt, visualize one just for fun
dot_data_f = tree.export_graphviz(rf_f[0], out_file=None, 
                         feature_names=list(train_set_f.columns),  
                         class_names=classes,
                         filled=True, rounded=True)  
graph = pydotplus.graph_from_dot_data(dot_data_f)  
Image(graph.create_png())

# %% [markdown]
# ### Naive Bayes

# %%
# define and fit gaussian model, predict on test and see results
gnb = GaussianNB()
gnb.fit(train_set_f, train_label_f)

test_pred_gnb = gnb.predict(test_set_f)

report_scores(test_label_f,test_pred_gnb)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.83      0.79      0.81        48
#    Low_Spend       0.93      0.96      0.94       925
#    Med_Spend       0.86      0.77      0.81       327
#
#     accuracy                           0.91      1300
#    macro avg       0.87      0.84      0.85      1300
# weighted avg       0.90      0.91      0.90      1300

# %% [markdown]
# ### KNN

# %%
# define and fit knn model, predict on test and see results
knn = KNeighborsClassifier(n_neighbors=5, algorithm='ball_tree', metric='minkowski').fit(train_set_f, train_label_f)

test_pred_knn = knn.predict(test_set_f)

report_scores(test_label_f,test_pred_knn)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.94      0.67      0.78        48
#    Low_Spend       0.96      0.97      0.96       925
#    Med_Spend       0.87      0.88      0.87       327
#
#     accuracy                           0.94      1300
#    macro avg       0.92      0.84      0.87      1300
# weighted avg       0.94      0.94      0.94      1300

# %% [markdown]
# ### SVM

# %%
# define and fit knn model, predict on test and see results
svm = SVC(kernel='sigmoid', C=0.6, gamma='scale', probability=True)
svm.fit(train_set_f, train_label_f)

test_pred_svm_f = svm.predict(test_set_f)

report_scores(test_label_f, test_pred_svm_f)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.49      0.46      0.47        48
#    Low_Spend       0.81      0.84      0.82       925
#    Med_Spend       0.43      0.40      0.42       327
#
#     accuracy                           0.71      1300
#    macro avg       0.58      0.56      0.57      1300
# weighted avg       0.70      0.71      0.71      1300

# %% [markdown]
# ***

# %% [markdown]
# # Classification with Neural Network

# %% [markdown]
# ### Preliminary functions
# The following functions are useful in many sections of this notebook, therefore they
# are put here at the beginning

# %% [markdown]
# Function to normalize the dataset:

# %%
def normalize_dataset(df):
    cols = df.columns
    scaler = MinMaxScaler()
    df = scaler.fit_transform(df.values)
    df = pd.DataFrame(df, columns=cols)
    return df

# %% [markdown]
# Function to print the dataset's composition:

# %%
def print_dataset_composition(train_set, train_labels, test_set, test_labels):
    assert(len(train_set) == len(train_labels))
    assert(len(test_set) == len(test_labels))
    print(f"{len(train_labels)} training samples:")
    print(f"\t- {len(train_labels[train_labels == 0])} samples for the class High_Spend")
    print(f"\t- {len(train_labels[train_labels == 1])} samples for the class Low_Spend")
    print(f"\t- {len(train_labels[train_labels == 2])} samples for the class Med_Spend")
    print(f"\n{len(test_labels)} test samples:")
    print(f"\t- {len(test_labels[test_labels == 0])} samples for the class High_Spend")
    print(f"\t- {len(test_labels[test_labels == 1])} samples for the class Low_Spend")
    print(f"\t- {len(test_labels[test_labels == 2])} samples for the class Med_Spend")

# %% [markdown]
# Function to create the NN model:

# %%
# Creates and returns a Keras NN model
def create_nn(size):
    """
    Characteristics:
        * 4 fully connected layers
            * the first 3 have 32 units
            * the last one has as many units as the number of classes, thus 3

        * activation function:
            * ReLU for the first 3 layers
            * Softmax for the output layer

        * Dropout of 0.2 is applied after every layer
    """
    model = Sequential()
    model.add(Dense(32, activation='relu', input_shape=(1,size)))
    model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(3, activation='softmax'))
    return model

# %% [markdown]
# Function to compile and fit the NN model:

# %%
def compile_fit(model, training_set, training_labels, epochs):
    """
    Compile and fits the model

    :param training_labels:
    :param training_set:
    :param model: Keras NN model to train
    :return: history of training to plot the metrics
    """
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    print(training_labels[0])
    hist = model.fit(
        training_set,
        training_labels,
        epochs=epochs,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )
    return hist

# %% [markdown]
# Function to plot the training results:

# %%
def plot_train_results(train_history):
    acc = train_history.history['accuracy']
    val_acc = train_history.history['val_accuracy']
    loss = train_history.history['loss']
    val_loss = train_history.history['val_loss']
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc, 'b', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'bo', label='Validation Accuracy')
    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'ro', label='Validation Loss')
    plt.title('Training and validation Acc')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy & Loss')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Function to create a report of the classification precision, recall, F1-score, support

# %%
# Function to create reports on the classification results
def report_scores(targets, predictions):
    classes = ['High_Spend','Low_Spend','Med_Spend']
    print(
        classification_report(
            targets,
            predictions,
            target_names=classes
        )
    )

# %% [markdown]
# ## Base dataframe
# Labels come from _K-means_ clustering algorithm

# %%
# Drop categorical columns and keep only the corresponding numerical ones
df.drop(columns=['MaxOrderMonth','Label'], inplace=True, errors='ignore')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4333 entries, 17850 to 12713
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TProd              4333 non-null   int64
#  1   DProd              4333 non-null   int64
#  2   MeanProdOrder      4333 non-null   float64
#  3   TSale              4333 non-null   float64
#  4   MeanSaleOrder      4333 non-null   float64
#  5   TRProd             4333 non-null   int64
#  6   MeanPSale          4333 non-null   float64
#  7   TOrder             4333 non-null   int64
#  8   MaxOrderMonth_num  4333 non-null   int32
#  9   Label_num          4333 non-null   int32
# dtypes: float64(4), int32(2), int64(4)
# memory usage: 338.5 KB

# %%
# Remove the labels from the dataframe and store them in a variable (pandas.Series)
labels = df.pop('Label_num')

# %%
df.boxplot(rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Normalize the dataset

# %%
df = normalize_dataset(df)
df.boxplot(rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Divide the dataframe to create training and testing sets

# %%
train_set, test_set, train_labels, test_labels = train_test_split(df, labels, stratify=labels, test_size=0.30)
print_dataset_composition(train_set, train_labels, test_set, test_labels)
# Out:
# 3033 training samples:
# 	- 18 samples for the class High_Spend
# 	- 2700 samples for the class Low_Spend
# 	- 315 samples for the class Med_Spend
#
# 1300 test samples:
# 	- 8 samples for the class High_Spend
# 	- 1157 samples for the class Low_Spend
# 	- 135 samples for the class Med_Spend

# %%
# Encode labels with one-hot
train_labels = to_categorical(train_labels, 3)
test_labels = to_categorical(test_labels, 3)

# %% [markdown]
# Create the Neural Network, compile it and train it

# %%
nn = create_nn(9)
history = compile_fit(nn, train_set, train_labels, epochs=20)
# Out:
# [0. 1. 0.]
# Epoch 1/20
# WARNING:tensorflow:Model was constructed with shape (None, 1, 9) for input Tensor("dense_input:0", shape=(None, 1, 9), dtype=float32), but it was called on an input with incompatible shape (None, 9).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 9) for input Tensor("dense_input:0", shape=(None, 1, 9), dtype=float32), but it was called on an input with incompatible shape (None, 9).
# 43/76 [===============>..............] - ETA: 0s - loss: 0.8416 - accuracy: 0.8503WARNING:tensorflow:Model was constructed with shape (None, 1, 9) for input Tensor("dense_input:0", shape=(None, 1, 9), dtype=float32), but it was called on an input with incompatible shape (None, 9).
# 76/76 [==============================] - 0s 3ms/step - loss: 0.6850 - accuracy: 0.8689 - val_loss: 0.4470 - val_accuracy: 0.8797
# Epoch 2/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8928 - val_loss: 0.3721 - val_accuracy: 0.8797
# Epoch 3/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.8928 - val_loss: 0.3121 - val_accuracy: 0.8797
# Epoch 4/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.2929 - accuracy: 0.8949 - val_loss: 0.2474 - val_accuracy: 0.8847
# Epoch 5/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.2346 - accuracy: 0.9081 - val_loss: 0.1730 - val_accuracy: 0.9209
# Epoch 6/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.1705 - accuracy: 0.9340 - val_loss: 0.1122 - val_accuracy: 0.9522
# Epoch 7/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.1417 - accuracy: 0.9456 - val_loss: 0.0835 - val_accuracy: 0.9802
# Epoch 8/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1084 - accuracy: 0.9608 - val_loss: 0.0837 - val_accuracy: 0.9572
# Epoch 9/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1007 - accuracy: 0.9646 - val_loss: 0.0644 - val_accuracy: 0.9687
# Epoch 10/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.0867 - accuracy: 0.9683 - val_loss: 0.0480 - val_accuracy: 0.9852
# Epoch 11/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.0719 - accuracy: 0.9753 - val_loss: 0.0384 - val_accuracy: 0.9934
# Epoch 12/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.0617 - accuracy: 0.9777 - val_loss: 0.0357 - val_accuracy: 0.9885
# Epoch 13/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.0602 - accuracy: 0.9773 - val_loss: 0.0350 - val_accuracy: 0.9885
# Epoch 14/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.0531 - accuracy: 0.9794 - val_loss: 0.0364 - val_accuracy: 0.9835
# Epoch 15/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.0501 - accuracy: 0.9798 - val_loss: 0.0312 - val_accuracy: 0.9885
# Epoch 16/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.0525 - accuracy: 0.9802 - val_loss: 0.0295 - val_accuracy: 0.9918
# Epoch 17/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9843 - val_loss: 0.0214 - val_accuracy: 0.9967
# Epoch 18/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9819 - val_loss: 0.0204 - val_accuracy: 0.9967
# Epoch 19/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.0425 - accuracy: 0.9810 - val_loss: 0.0220 - val_accuracy: 0.9951
# Epoch 20/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 0.9856 - val_loss: 0.0195 - val_accuracy: 0.9967

# %% [markdown]
# Plot the training results:

# %%
plot_train_results(history)

# %% [markdown]
# Test the model on the test set

# %%
test_predictions = nn.predict_classes(test_set)
test_predictions = to_categorical(test_predictions, 3)
report_scores(test_labels, test_predictions)
# Out:
# WARNING:tensorflow:From <ipython-input-68-c019dbec2606>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 9) for input Tensor("dense_input:0", shape=(None, 1, 9), dtype=float32), but it was called on an input with incompatible shape (None, 9).
#               precision    recall  f1-score   support
#
#   High_Spend       1.00      0.88      0.93         8
#    Low_Spend       0.99      1.00      1.00      1157
#    Med_Spend       0.98      0.96      0.97       135
#
#    micro avg       0.99      0.99      0.99      1300
#    macro avg       0.99      0.94      0.97      1300
# weighted avg       0.99      0.99      0.99      1300
#  samples avg       0.99      0.99      0.99      1300

# %% [markdown]
# ## Dataframe coming from Fuzzy C-Means
# Labels come from _Fuzzy C-Means_ clustering algorithm

# %%
#Normalize the dataset
df_f = normalize_dataset(df_f)

# Divide the dataframe to create training and testing sets
train_set, test_set, train_labels, test_labels = train_test_split(df_f, labels, stratify=labels, test_size=0.30)
print_dataset_composition(train_set, train_labels, test_set, test_labels)

# Encode labels with one-hot
train_labels = to_categorical(train_labels, 3)
test_labels = to_categorical(test_labels, 3)
# Out:
# 3033 training samples:
# 	- 18 samples for the class High_Spend
# 	- 2700 samples for the class Low_Spend
# 	- 315 samples for the class Med_Spend
#
# 1300 test samples:
# 	- 8 samples for the class High_Spend
# 	- 1157 samples for the class Low_Spend
# 	- 135 samples for the class Med_Spend

# %% [markdown]
# Create the Neural Network, compile it and train it

# %%
nn = create_nn(12)
history = compile_fit(nn, train_set, train_labels, epochs=20)
# Out:
# [0. 1. 0.]
# Epoch 1/20
# WARNING:tensorflow:Model was constructed with shape (None, 1, 12) for input Tensor("dense_8_input:0", shape=(None, 1, 12), dtype=float32), but it was called on an input with incompatible shape (None, 12).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 12) for input Tensor("dense_8_input:0", shape=(None, 1, 12), dtype=float32), but it was called on an input with incompatible shape (None, 12).
# 40/76 [==============>...............] - ETA: 0s - loss: 0.7032 - accuracy: 0.8891WARNING:tensorflow:Model was constructed with shape (None, 1, 12) for input Tensor("dense_8_input:0", shape=(None, 1, 12), dtype=float32), but it was called on an input with incompatible shape (None, 12).
# 76/76 [==============================] - 0s 3ms/step - loss: 0.5868 - accuracy: 0.8883 - val_loss: 0.4122 - val_accuracy: 0.8847
# Epoch 2/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8916 - val_loss: 0.3690 - val_accuracy: 0.8847
# Epoch 3/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8916 - val_loss: 0.3289 - val_accuracy: 0.8847
# Epoch 4/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8949 - val_loss: 0.2822 - val_accuracy: 0.8896
# Epoch 5/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.2949 - accuracy: 0.9085 - val_loss: 0.2347 - val_accuracy: 0.9226
# Epoch 6/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.2426 - accuracy: 0.9130 - val_loss: 0.1970 - val_accuracy: 0.9242
# Epoch 7/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.2112 - accuracy: 0.9196 - val_loss: 0.1600 - val_accuracy: 0.9242
# Epoch 8/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.9134 - val_loss: 0.1433 - val_accuracy: 0.9374
# Epoch 9/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9237 - val_loss: 0.1359 - val_accuracy: 0.9242
# Epoch 10/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1708 - accuracy: 0.9192 - val_loss: 0.1330 - val_accuracy: 0.9242
# Epoch 11/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.1657 - accuracy: 0.9254 - val_loss: 0.1150 - val_accuracy: 0.9473
# Epoch 12/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1584 - accuracy: 0.9332 - val_loss: 0.1081 - val_accuracy: 0.9489
# Epoch 13/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1531 - accuracy: 0.9357 - val_loss: 0.1018 - val_accuracy: 0.9703
# Epoch 14/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1457 - accuracy: 0.9357 - val_loss: 0.0943 - val_accuracy: 0.9555
# Epoch 15/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 0.9411 - val_loss: 0.0829 - val_accuracy: 0.9720
# Epoch 16/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1248 - accuracy: 0.9477 - val_loss: 0.0856 - val_accuracy: 0.9588
# Epoch 17/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.1278 - accuracy: 0.9497 - val_loss: 0.0792 - val_accuracy: 0.9654
# Epoch 18/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.1061 - accuracy: 0.9592 - val_loss: 0.0656 - val_accuracy: 0.9736
# Epoch 19/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.9571 - val_loss: 0.0568 - val_accuracy: 0.9868
# Epoch 20/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 0.9588 - val_loss: 0.0522 - val_accuracy: 0.9852

# %% [markdown]
# Plot the training results:

# %%
plot_train_results(history)

# %% [markdown]
# Test the model on the test set

# %%
test_predictions = nn.predict_classes(test_set)
test_predictions = to_categorical(test_predictions, 3)
report_scores(test_labels, test_predictions)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1, 12) for input Tensor("dense_8_input:0", shape=(None, 1, 12), dtype=float32), but it was called on an input with incompatible shape (None, 12).
#               precision    recall  f1-score   support
#
#   High_Spend       0.89      1.00      0.94         8
#    Low_Spend       0.97      1.00      0.98      1157
#    Med_Spend       0.98      0.74      0.84       135
#
#    micro avg       0.97      0.97      0.97      1300
#    macro avg       0.95      0.91      0.92      1300
# weighted avg       0.97      0.97      0.97      1300
#  samples avg       0.97      0.97      0.97      1300

# %% [markdown]
# ## Base dataframe with SMOTE oversampling
# Labels come from _K-Means_ clustering algorithm

# %% [markdown]
# ### Normalize and SMOTE

# %%
#Normalize the dataset
cols = df.columns
scaler = MinMaxScaler()
df = scaler.fit_transform(df.values)
df = pd.DataFrame(df, columns=cols)

# Pick validation set from the complete df
df, val_set, labels, val_labels = train_test_split(df, labels, stratify=labels, test_size=0.5)

# SMOTE --> balance the number of entries of each class
smote = SMOTE(
    sampling_strategy='not majority',    # resample all classes but the majority one
    k_neighbors=5
)
df, labels = smote.fit_resample(df, labels)

# Divide the dataframe to create training and testing sets
train_set, test_set, train_labels, test_labels = train_test_split(df, labels, stratify=labels, test_size=0.30)

assert(len(train_set) == len(train_labels))
assert(len(val_set) == len(val_labels))
assert(len(test_set) == len(test_labels))
print(f"\n{len(train_labels)} training samples:")
print(f"\t- {len(train_labels[train_labels == 0])} samples for the class High_Spend")
print(f"\t- {len(train_labels[train_labels == 1])} samples for the class Low_Spend")
print(f"\t- {len(train_labels[train_labels == 2])} samples for the class Med_Spend")
print(f"\n{len(test_labels)} validation samples:")
print(f"\t- {len(val_labels[val_labels == 0])} samples for the class High_Spend")
print(f"\t- {len(val_labels[val_labels == 1])} samples for the class Low_Spend")
print(f"\t- {len(val_labels[val_labels == 2])} samples for the class Med_Spend")
print(f"\n{len(test_labels)} test samples:")
print(f"\t- {len(test_labels[test_labels == 0])} samples for the class High_Spend")
print(f"\t- {len(test_labels[test_labels == 1])} samples for the class Low_Spend")
print(f"\t- {len(test_labels[test_labels == 2])} samples for the class Med_Spend")

# Encode labels with one-hot
train_labels = to_categorical(train_labels, 3)
val_labels = to_categorical(val_labels, 3)
test_labels = to_categorical(test_labels, 3)
# Out:
# 4048 training samples:
# 	- 1349 samples for the class High_Spend
# 	- 1349 samples for the class Low_Spend
# 	- 1350 samples for the class Med_Spend
#
# 1736 validation samples:
# 	- 13 samples for the class High_Spend
# 	- 1929 samples for the class Low_Spend
# 	- 225 samples for the class Med_Spend
#
# 1736 test samples:
# 	- 579 samples for the class High_Spend
# 	- 579 samples for the class Low_Spend
# 	- 578 samples for the class Med_Spend

# %% [markdown]
# Create the Neural Network, compile it and train it

# %%
nn = Sequential([
    Dense(16, activation='relu'),
    Dropout(0.5),
    Dense(16, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

nn.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
history = nn.fit(
    train_set,
    train_labels,
    epochs=27,
    batch_size=32,
    validation_data=(val_set, val_labels),
    verbose=1
)
# Out:
# Epoch 1/27
# WARNING:tensorflow:Layer dense_12 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 127/127 [==============================] - 0s 2ms/step - loss: 1.0560 - accuracy: 0.4234 - val_loss: 0.9512 - val_accuracy: 0.8980
# Epoch 2/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.9044 - accuracy: 0.5620 - val_loss: 0.7628 - val_accuracy: 0.9054
# Epoch 3/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.7235 - accuracy: 0.6388 - val_loss: 0.6632 - val_accuracy: 0.9197
# Epoch 4/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.6247 - accuracy: 0.6806 - val_loss: 0.6324 - val_accuracy: 0.9492
# Epoch 5/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.5536 - accuracy: 0.7208 - val_loss: 0.5687 - val_accuracy: 0.9511
# Epoch 6/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.5110 - accuracy: 0.7586 - val_loss: 0.5241 - val_accuracy: 0.9769
# Epoch 7/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.4723 - accuracy: 0.7893 - val_loss: 0.4482 - val_accuracy: 0.9778
# Epoch 8/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.8286 - val_loss: 0.4068 - val_accuracy: 0.9815
# Epoch 9/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.3833 - accuracy: 0.8468 - val_loss: 0.3644 - val_accuracy: 0.9802
# Epoch 10/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.3551 - accuracy: 0.8575 - val_loss: 0.3294 - val_accuracy: 0.9802
# Epoch 11/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.3251 - accuracy: 0.8718 - val_loss: 0.3166 - val_accuracy: 0.9612
# Epoch 12/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.3165 - accuracy: 0.8903 - val_loss: 0.2653 - val_accuracy: 0.9732
# Epoch 13/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.2922 - accuracy: 0.8975 - val_loss: 0.2594 - val_accuracy: 0.9686
# Epoch 14/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.2627 - accuracy: 0.9116 - val_loss: 0.2221 - val_accuracy: 0.9668
# Epoch 15/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.2474 - accuracy: 0.9118 - val_loss: 0.2005 - val_accuracy: 0.9751
# Epoch 16/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.9244 - val_loss: 0.2016 - val_accuracy: 0.9654
# Epoch 17/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.2235 - accuracy: 0.9271 - val_loss: 0.2117 - val_accuracy: 0.9543
# Epoch 18/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.2195 - accuracy: 0.9222 - val_loss: 0.1769 - val_accuracy: 0.9700
# Epoch 19/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9281 - val_loss: 0.1794 - val_accuracy: 0.9672
# Epoch 20/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.9402 - val_loss: 0.1717 - val_accuracy: 0.9645
# Epoch 21/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.1957 - accuracy: 0.9348 - val_loss: 0.1437 - val_accuracy: 0.9820
# Epoch 22/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.1894 - accuracy: 0.9377 - val_loss: 0.1443 - val_accuracy: 0.9788
# Epoch 23/27
# 127/127 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.93 - 0s 1ms/step - loss: 0.1842 - accuracy: 0.9400 - val_loss: 0.1329 - val_accuracy: 0.9815
# Epoch 24/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.1772 - accuracy: 0.9410 - val_loss: 0.1455 - val_accuracy: 0.9746
# Epoch 25/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.1733 - accuracy: 0.9454 - val_loss: 0.1441 - val_accuracy: 0.9714
# Epoch 26/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.1707 - accuracy: 0.9442 - val_loss: 0.1416 - val_accuracy: 0.9737
# Epoch 27/27
# 127/127 [==============================] - 0s 1ms/step - loss: 0.1664 - accuracy: 0.9447 - val_loss: 0.1167 - val_accuracy: 0.9838

# %% [markdown]
# Plot the training results:

# %%
plot_train_results(history)

# %% [markdown]
# Test the model on the test set

# %%
test_predictions = nn.predict_classes(test_set)
test_predictions = to_categorical(test_predictions, 3)
report_scores(test_labels, test_predictions)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       1.00      1.00      1.00       579
#    Low_Spend       1.00      0.99      1.00       579
#    Med_Spend       0.99      1.00      1.00       578
#
#    micro avg       1.00      1.00      1.00      1736
#    macro avg       1.00      1.00      1.00      1736
# weighted avg       1.00      1.00      1.00      1736
#  samples avg       1.00      1.00      1.00      1736

# %% [markdown]
# # Alternative Features

# %% [markdown]
# For this analysis the dataset *customer_dataframe_big.csv* will be used, since it contains all the features for the customers.
# Then, joining with the dataset created from Fuzzy K-Means we add the labeling to the various customers.

# %%
df = pd.read_csv('datasets/clustered_fuzzy_dataframe.csv', sep='\t', index_col=0)
df_customer = pd.read_csv('datasets/customer_dataframe_big.csv', sep='\t', index_col=0)

df_customer.set_index("CustomerID", inplace = True)
df_customer['Label'] = df['Label']

# Size of different classes in the dataset
print("-------------------------")
for i in ['Low_Spend', 'Med_Spend', 'High_Spend']:
    print(i, len(df_customer[df_customer['Label'] == i]))
# Out:
# -------------------------
# Low_Spend 3084
# Med_Spend 1088
# High_Spend 161

# %% [markdown]
# The target of this analysis is to use all the features that are not exploited by the clustering to assign the customers to a class.

# %%
# Drop all the features that are not time dependent and not usefull to generalize the behaviour of a customer
df_customer = discretize_data(df_customer,['MaxOrderMonth','Label'])
df_aux = df_customer.drop(columns=['TProd', 'MaxPO', 'MinPO', 'MeanProdOrder', 'TSaleWRet', 'MinPSale', 'MaxPSale', 'MeanSaleOrder',
                                   'MeanPSale', 'MaxOrderMonth', 'MaxOrderMonth', 'MaxOrderDay', 'Label', 'TRProd', 
                                   'SETSaleQta', 'SESaleQtaOrder', 'SEShoppingDays', 'DProd', 'TSale', 'TOrder'], errors='ignore')
df_class = df_aux.copy()
df_class.tail()
# Out:
#             OrderMonth  ProdMonth  SaleMonth  MonthPresence  MeanTimeGap  \
# CustomerID
# 13436            0.083      6.333     16.407          0.083          0.0
# 15520            0.083     26.167     28.625          0.083          0.0
# 13298            0.083      8.000     30.000          0.083          0.0
# 14569            0.083      6.583     18.949          0.083          0.0
# 12713            0.083     42.083     66.212          0.083          0.0
#
#             MaxOrderMonth_num  Label_num
# CustomerID
# 13436                       2          1
# 15520                       2          2
# 13298                       2          1
# 14569                       2          1
# 12713                       2          2

# %% [markdown]
# # Decision Tree

# %%
label = df_class.pop('Label_num')
train_set, test_set, train_label, test_label = train_test_split(df_class, label, stratify =label, test_size=0.35)
print(f"Class HighSpend\nTrain: {len(train_label[train_label == 0])}\nTest: {len(test_label[test_label == 0])}")
# Out:
# Class HighSpend
# Train: 105
# Test: 56

# %%
dt = tree.DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=3, min_samples_split=17, min_samples_leaf=20)
dt = dt.fit(train_set, train_label)
classes = ['High_Spend','Low_Spend','Med_Spend']
dot_data = tree.export_graphviz(dt, out_file=None, feature_names=list(train_set.columns), class_names=classes, filled=True, rounded=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %%
train_pred_dt = dt.predict(train_set)
test_pred_dt = dt.predict(test_set)
report_scores(test_label, test_pred_dt)
# Out:
#               precision    recall  f1-score   support
#
#   High_Spend       0.94      0.29      0.44        56
#    Low_Spend       0.78      0.97      0.86      1080
#    Med_Spend       0.73      0.30      0.43       381
#
#     accuracy                           0.78      1517
#    macro avg       0.82      0.52      0.58      1517
# weighted avg       0.77      0.78      0.74      1517

# %% [markdown]
# ***
